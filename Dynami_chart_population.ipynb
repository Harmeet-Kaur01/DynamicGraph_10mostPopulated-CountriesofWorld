# %% [markdown]
# ##                                    POPULATION DYNAMIC CHART

# %% [markdown]
# Download FFMPEG on system to run dynamic charts on system

# %%
#importing the required libraries 
import pandas as pd, numpy as np
import bar_chart_race as bcr

# %%
#importing the data
HR = pd.read_csv(r'C:\Users\Windows\OneDrive\Desktop\population.csv').set_index('YEAR')
HR
# Out:
#            China       India  European Union  United States  Indonesia  \
# YEAR
# 2000  1262645000  1059633675       429342455      282162411  214072421
# 2001  1271850000  1078970907       429910140      284968955  217112437
# 2002  1280400000  1098313039       430898141      287625193  220115092
# 2003  1288400000  1117415123       432434810      290107933  223080121
# 2004  1296075000  1136264583       434059923      292805298  225938595
# 2005  1303720000  1154638713       435600393      295516599  228805144
# 2006  1311020000  1172373788       437014860      298379912  231797427
# 2007  1317885000  1189691809       438484072      301231207  234858289
# 2008  1324655000  1206734806       439892213      304093966  237936543
# 2009  1331260000  1223640160       440934530      306771529  240981299
# 2010  1337705000  1240613620       441552554      309327143  244016173
# 2011  1345035000  1257621191       440769682      311583481  247099697
# ...

# %%
bcr.bar_chart_race(df=HR ,sort = 'desc',title='HIGHEST POPULATION OF TOP 10 COUNTRIES')
# Out:
# C:\Users\Windows\anaconda3\lib\site-packages\bar_chart_race\_make_chart.py:286: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(self.df_values.columns)
# C:\Users\Windows\anaconda3\lib\site-packages\bar_chart_race\_make_chart.py:287: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels([max_val] * len(ax.get_xticks()))
# <video width="962" height="504" controls autoplay loop>
#   <source type="video/mp4" src="...
